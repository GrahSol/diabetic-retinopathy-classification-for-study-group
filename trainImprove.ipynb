# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !git clone https://github.com/GrahSol/diabetic-retinopathy-classification-for-study-group.git
# Out:
# Cloning into 'diabetic-retinopathy-classification-for-study-group'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 43 (delta 1), reused 1 (delta 1), pack-reused 38 (from 1)
# Receiving objects: 100% (43/43), 13.53 MiB | 24.09 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd diabetic-retinopathy-classification-for-study-group
# Out:
# /content/diabetic-retinopathy-classification-for-study-group

# %%
# !pip install ultralytics roboflow tensorboard
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.8/195.8 kB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 74.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Q1flzyg1J8Z2OMweLXf3")
project = rf.workspace("weapon-mpr3p").project("ddr-dataset-yyvzp")
version = project.version(1)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DDR-dataset-1 in folder:: 100%|██████████| 13575/13575 [00:01<00:00, 10824.17it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11n-cls.pt")

model.train(
    data=dataset.location,
    epochs=5,
    imgsz=224,
    batch=64,
    name="ddr_224_nano",
    device=0
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.46 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !zip -r hasil.zip runs/classify/ddr_224_nano
from google.colab import files
files.download("hasil.zip")
# Out:
#   adding: runs/classify/ddr_224_nano/ (stored 0%)
#   adding: runs/classify/ddr_224_nano/val_batch1_pred.jpg (deflated 23%)
#   adding: runs/classify/ddr_224_nano/confusion_matrix_normalized.png (deflated 23%)
#   adding: runs/classify/ddr_224_nano/val_batch2_labels.jpg (deflated 20%)
#   adding: runs/classify/ddr_224_nano/val_batch0_pred.jpg (deflated 25%)
#   adding: runs/classify/ddr_224_nano/train_batch2.jpg (deflated 14%)
#   adding: runs/classify/ddr_224_nano/train_batch1.jpg (deflated 17%)
#   adding: runs/classify/ddr_224_nano/weights/ (stored 0%)
#   adding: runs/classify/ddr_224_nano/weights/best.pt (deflated 9%)
#   adding: runs/classify/ddr_224_nano/weights/last.pt (deflated 9%)
#   adding: runs/classify/ddr_224_nano/val_batch2_pred.jpg (deflated 20%)
#   adding: runs/classify/ddr_224_nano/train_batch0.jpg (deflated 15%)
#   adding: runs/classify/ddr_224_nano/results.png (deflated 8%)
#   adding: runs/classify/ddr_224_nano/args.yaml (deflated 53%)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11s-cls.pt")

model.train(
    data=dataset.location,
    epochs=30,      # lebih lama
    imgsz=320,      # lebih detail
    batch=64,
    device=0
)
# Out:
# ...
# Ultralytics 8.4.46 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !zip -r hasil_final.zip runs/classify/train
from google.colab import files
files.download("hasil_final.zip")
# Out:
#   adding: runs/classify/train/ (stored 0%)
#   adding: runs/classify/train/val_batch1_pred.jpg (deflated 26%)
#   adding: runs/classify/train/confusion_matrix_normalized.png (deflated 23%)
#   adding: runs/classify/train/val_batch2_labels.jpg (deflated 24%)
#   adding: runs/classify/train/val_batch0_pred.jpg (deflated 27%)
#   adding: runs/classify/train/train_batch2.jpg (deflated 16%)
#   adding: runs/classify/train/train_batch2982.jpg (deflated 19%)
#   adding: runs/classify/train/train_batch1.jpg (deflated 19%)
#   adding: runs/classify/train/weights/ (stored 0%)
#   adding: runs/classify/train/weights/best.pt (deflated 8%)
#   adding: runs/classify/train/weights/last.pt (deflated 8%)
#   adding: runs/classify/train/val_batch2_pred.jpg (deflated 23%)
#   adding: runs/classify/train/train_batch0.jpg (deflated 16%)
#   adding: runs/classify/train/results.png (deflated 7%)
#   adding: runs/classify/train/args.yaml (deflated 53%)
# ...
